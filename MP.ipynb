# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %%
import os

# %%
import numpy as np

# %%
path = '/Users/janvirite/Downloads/Img to vid/opencv_project'
vid_name = 'Test.mp4'
list_ext = ['jpeg', 'jpg', 'png']
dic_dur = {'fast':1, 'medium': 2, 'slow': 4}

# %%
images = []
for file in os.listdir(os.path.join(path,'imgs')): 
    if file.split('.')[1] in list_ext:
       # print(file)
        images.append(os.path.join(path,'imgs',file))

# %%
images
# Out:
# ['/Users/janvirite/Downloads/Img to vid/opencv_project/imgs/img4.jpeg',
#  '/Users/janvirite/Downloads/Img to vid/opencv_project/imgs/img2.jpeg',
#  '/Users/janvirite/Downloads/Img to vid/opencv_project/imgs/img3.jpeg',
#  '/Users/janvirite/Downloads/Img to vid/opencv_project/imgs/img1.jpeg']

# %%
img_dur = ['medium', 'slow', 'fast', 'medium']

# %%
cv2_fourcc = cv2.VideoWriter_fourcc(*'mp4v')
frame = cv2.imread(images[0]) #frame of images (border of image)
size = list(frame.shape) 
video = cv2.VideoWriter(os.path.join(path, vid_name), cv2_fourcc, 1, size[:-1])

# %%
video
# Out:
# < cv2.VideoWriter 0x7f9500a1cf10>

# %%
size
# Out:
# [500, 500, 3]

# %%
for img,dur in (zip)(images, img_dur):
    t = dic_dur[dur]
    for i in range(int(t*fps)):
        video.write(img)
video.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vy/6blffwtj3n7241wfm35z4s5w0000gn/T/ipykernel_47135/4021337136.py in <module>
#       1 for img,dur in (zip)(images, img_dur):
#       2     t = dic_dur[dur]
# ----> 3     for i in range(int(t*fps)):
#       4         video.write(img)
#       5 video.release()
#
# NameError: name 'fps' is not defined

# %%
fps
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vy/6blffwtj3n7241wfm35z4s5w0000gn/T/ipykernel_47135/3206452030.py in <module>
# ----> 1 fps
#
# NameError: name 'fps' is not defined

# %%
cap = cv2.VideoCapture(0)
cap. set(cv2.CAP_PROP_FPS, 60)
# Out:
# True

# %%
while True:
    ret, frame = cap.read() 
    fps = int(cap.get(cv2.CAP_PROP_FPS)) # access FPS property 
    print("fps", fps) # print fps
    font = cv2.FONT_HERSHEY_SIMPLEX #font to apply on text
    cv2.putText(frame, str(fps), (50, 50), font, 1, (0, 0, 255), 2) # add text on frame cv2.imshow("Live Streaming", frame) #display frame/image
    key = cv2.waitKey(1) # wait till key press if key == ord("q"): # exit Loop on 'q' key press
break
cap.release() # release video capture object
cv2.destroyAllWindows() # destroy all frame windows
# Out:
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# fps 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/vy/6blffwtj3n7241wfm35z4s5w0000gn/T/ipykernel_47135/1063010024.py in <module>
#       1 while True:
# ----> 2     ret, frame = cap.read()
#       3     fps = int(cap.get(cv2.CAP_PROP_FPS)) # access FPS property
#       4     print("fps", fps) # print fps
#       5     font = cv2.FONT_HERSHEY_SIMPLEX #font to apply on text
#
# KeyboardInterrupt:

# %%
from imutils.video import FPS

# %%
fps = FPS().start()
cv2.imshow("Frame", frame)
cv2.waitKey(1)
fps.update()
fps.stop()
print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))
# Out:
# [INFO] elasped time: 0.53
# [INFO] approx. FPS: 1.89

# %%
import cv2
import os

image_folder = 'images'
video_name = 'Test.mp4'
path = '/Users/janvirite/Downloads/Img to vid/opencv_project'

images = [img for img in os.listdir(image_folder)
          if img.endswith('jpg','png','jpeg')]
frame = cv2.imread(os.path.join(image_folder, images[0]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name, 0, 1, (width,height))

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/vy/6blffwtj3n7241wfm35z4s5w0000gn/T/ipykernel_47135/2792653084.py in <module>
#       6 path = '/Users/janvirite/Downloads/Img to vid/opencv_project'
#       7
# ----> 8 images = [img for img in os.listdir(image_folder)
#       9           if img.endswith('jpg','png','jpeg')]
#      10 frame = cv2.imread(os.path.join(image_folder, images[0]))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images'
